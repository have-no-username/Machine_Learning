# %% [markdown]
# <a href="https://colab.research.google.com/github/mizan-25/Machine_Learning/blob/main/Gradient_Decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
m_curr = b_curr=0
iteration=10000
n=len(x)
learning_rate=0.08
for i in range(iteration):
  yd=m_curr*x+b_curr
  cost=(1/n)*sum((y-yd)**2)
  md=-(2/n)*sum(x*(y-yd))
  mb=-(2/n)*sum(y-yd)
  m_curr=m_curr-learning_rate*md
  b_curr=b_curr-learning_rate*mb
  print("m {} ,b {},iteration {},cost {}".format(m_curr,b_curr,i,cost))
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.000000000000001 ,b 2.9999999999999947,iteration 5000,cost 1.0255191767873153e-29
# m 2.000000000000002 ,b 2.999999999999995,iteration 5001,cost 1.0255191767873153e-29
# m 2.000000000000001 ,b 2.9999999999999947,iteration 5002,cost 1.0255191767873153e-29
# m 2.000000000000002 ,b 2.999999999999995,iteration 5003,cost 1.0255191767873153e-29
# m 2.000000000000001 ,b 2.9999999999999947,iteration 5004,cost 1.0255191767873153e-29
# m 2.000000000000002 ,b 2.999999999999995,iteration 5005,cost 1.0255191767873153e-29
# m 2.000000000000001 ,b 2.9999999999999947,iteration 5006,cost 1.0255191767873153e-29
# m 2.000000000000002 ,b 2.999999999999995,iteration 5007,cost 1.0255191767873153e-29
# m 2.000000000000001 ,b 2.9999999999999947,iteration 5008,cost 1.0255191767873153e-29
# m 2.000000000000002 ,b 2.999999999999995,iteration 5009,cost 1.0255191767873153e-29
# ...
